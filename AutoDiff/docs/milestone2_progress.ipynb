# %% [markdown]
# ## Milestone 2 - Progress

# %% [markdown]
# Here are the tasks we completed after the submission of M1, as well as the individual tasks assigned before the submission of M2 (Nov 19).
# For Milestone 1, we divided our work based on the sections of documentation. For Milestone2, we make sure that everybody envolves in both writing codes and
# developing the documentation.
#
# Timeline
#
# | Task          | Contributor           | Due Date  | Progress
# | ------------- |:-------------:| --------:|--------:|
# | Milestone 1 Updates - Meeting & Discussion & Research  | Jiahui/Yujie/Wenqi | Nov 3| Done
# | Milestone 1 Updates - Dual Number Background  | Yujie | Nov 3| Done
# | Milestone 1 Updates - Reverse Mode | Wenqi | Nov 3| Done
# | Milestone 1 Updates - Main class implementation example on Dual/Reverse  | Jiahui | Nov 3| Done
# | Milestone 1 Updates     | Jiahui/Yujie/Wenqi | Nov 3| Done
# | Auto Diff Main Class, Forward Mode     | Jiahui | Nov 13  | On Track
# | Elementary Function Class      | Yujie     |   Nov 13 | On Track
# | Auto Diff Reverse Mode Class     | Wenqi | Nov 13 | On Track
# | Test Suite     | Wenqi | Nov 13 | On Track
# | Re-iterate/Discussion/Merge     | Jiahui/Yujie/Wenqi | Nov 15 | On Track
# | Packaging     | Jiahui | Nov 17 | On Track
# | Documentation updates - Intro and background    |  Yujie   |   Nov 19 |   On Track
# | Documentation updates - How to use package    |   Yujie  |   Nov 19 | On Track
# | Documentation updates - Software Organization    |  Wenqi   |   Nov 19 | On Track
# | Documentation updates - Implementation Details   | Jiahui    |   Nov 19 | On Track
# | Future Features   |   Wenqi  |   Nov 19 | On Track
